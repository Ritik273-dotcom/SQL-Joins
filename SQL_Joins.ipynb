# %% [markdown]
# Question 1. Retrieve all customers who have placed at least one order.
#
# Answer: ![WhatsApp Image 2026-05-16 at 17.27.01.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Question 2. Retrieve all customers and their orders, including customers who have not placed any orders.
#
# Answer: ![WhatsApp Image 2026-05-16 at 17.32.53.jpeg](data:image/jpeg;base64,...)
#
#
# ![WhatsApp Image 2026-05-16 at 17.32.53 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Question 3. Retrieve all orders and their corresponding customers, including orders placed by unknown
# customers.
#
# Answer: ![WhatsApp Image 2026-05-16 at 17.36.07.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Question 4. Display all customers and orders, whether matched or not.
#
# Answer: ![WhatsApp Image 2026-05-16 at 17.42.08.jpeg](data:image/jpeg;base64,...)
#
#
# ![WhatsApp Image 2026-05-16 at 17.42.08 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Question 5. Find customers who have not placed any orders.
#
# Answer: ![WhatsApp Image 2026-05-16 at 17.44.33.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Question 6. Retrieve customers who made payments but did not place any orders.
#
# Answer: ![WhatsApp Image 2026-05-16 at 17.49.23.jpeg](data:image/jpeg;base64,...)
#
#
# ![WhatsApp Image 2026-05-16 at 17.49.23.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Question 7. Generate a list of all possible combinations between Customers and Orders.
#
# Answer: ![WhatsApp Image 2026-05-16 at 17.51.26.jpeg](data:image/jpeg;base64,...)
#
#
# ![WhatsApp Image 2026-05-16 at 17.51.27.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Question 8. Show all customers along with order and payment amounts in one table.
#
# Answer: ![WhatsApp Image 2026-05-16 at 17.56.02.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Question 9. Retrieve all customers who have both placed orders and made payments.
#
# Answer: ![WhatsApp Image 2026-05-16 at 17.58.57.jpeg](data:image/jpeg;base64,...)
#
#
# ![WhatsApp Image 2026-05-16 at 17.58.57 (1).jpeg](data:image/jpeg;base64,...)
